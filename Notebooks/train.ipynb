# %%
# !python train.py
# Out:
# Device being used: cuda:0
# Training decoder unet with encoder resnet18 from scratch ...
# Total params: 15.16M
# Use inria mean std stats: [[0.41776216 0.43993309 0.39138562]
#  [0.18476704 0.16793099 0.15915148]]
# Training model on the inria dataset
# [train] Epoch: 0/11 xent: 0.968 IoU: 0.536
# Execution time: 458.6479451999985
#
# [valid] Epoch: 0/11 xent: 0.787 IoU: 0.605
# Execution time: 78.61232060000475
#
# [train] Epoch: 1/11 xent: 0.721 IoU: 0.654
# Execution time: 428.2381588999997
#
# [valid] Epoch: 1/11 xent: 0.684 IoU: 0.654
# Execution time: 78.81928580000385
#
# [train] Epoch: 2/11 xent: 0.685 IoU: 0.671
# Execution time: 428.5329983999982
#
# [valid] Epoch: 2/11 xent: 0.679 IoU: 0.662
# Execution time: 78.4264708999981
#
# [train] Epoch: 3/11 xent: 0.641 IoU: 0.691
# Execution time: 427.8489589000019
#
# [valid] Epoch: 3/11 xent: 0.640 IoU: 0.694
# Execution time: 78.91126839999924
#
# [train] Epoch: 4/11 xent: 0.615 IoU: 0.702
# Execution time: 434.8951132000002
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA TITAN V'

# %%
# !python evaluate.py
# Out:
# Device being used: cuda:0
# Loaded from E:\Research\Notebooks\model_save\train_8\ecresnet18_dcunet_dsinria_lre1e-03_lrd1e-02_ep11_bs5_ds50_dr0p1_crxent\epoch-11.pth.tar
# Traceback (most recent call last):
#   File "e:\Research\Notebooks\evaluate.py", line 57, in <module>
#     main()
#   File "e:\Research\Notebooks\evaluate.py", line 51, in main
#     evaluator = eval_utils.Evaluator('mnih', DATA_DIR, tsfm_valid, device)
#   File "c:\Users\Derrick\anaconda3_2\lib\site-packages\mrs_utils\eval_utils.py", line 378, in __init__
#     from data.mnih import preprocess
#   File "e:\Research\Notebooks\data\mnih\preprocess.py", line 22, in <module>
#     MODES = os.listdir(os.path.join(DATA_DIR, SPLITS[0])) # sat (input), map (target)
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'E:\\Research\\Notebooks\\data\\inria\\images\\train'
