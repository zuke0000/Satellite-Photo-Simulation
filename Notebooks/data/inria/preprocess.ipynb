# %%
# !python preprocess.py
# Out:
# [[nan nan nan]
#  [nan nan nan]]
# City-wise:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Tile-wise:   0%|          | 0/36 [00:00<?, ?it/s]
#
# Tile-wise:   3%|▎         | 1/36 [00:01<00:51,  1.47s/it]
#
# Tile-wise:   6%|▌         | 2/36 [00:02<00:49,  1.46s/it]
#
# Tile-wise:   8%|▊         | 3/36 [00:04<00:47,  1.45s/it]
#
# Tile-wise:  11%|█         | 4/36 [00:05<00:45,  1.41s/it]
#
# Tile-wise:  14%|█▍        | 5/36 [00:07<00:42,  1.38s/it]
#
# Tile-wise:  17%|█▋        | 6/36 [00:08<00:40,  1.35s/it]
#
# Tile-wise:  19%|█▉        | 7/36 [00:09<00:39,  1.35s/it]
#
# Tile-wise:  22%|██▏       | 8/36 [00:11<00:39,  1.41s/it]
#
# Tile-wise:  25%|██▌       | 9/36 [00:12<00:38,  1.43s/it]
#
# Tile-wise:  28%|██▊       | 10/36 [00:14<00:36,  1.40s/it]
#
# Tile-wise:  31%|███       | 11/36 [00:15<00:34,  1.39s/it]
#
# Tile-wise:  33%|███▎      | 12/36 [00:16<00:33,  1.41s/it]
#
# Tile-wise:  36%|███▌      | 13/36 [00:18<00:31,  1.38s/it]
#
# ...

# %%
import os
os.path
# Out:
# <module 'ntpath' from 'c:\\Users\\Derrick\\anaconda3_2\\lib\\ntpath.py'>

# %%
1 + (1==1)
# Out:
# 2
