# %%
# !python data_loader.py
import matplotlib.pyplot as plt
plt.show()
# Out:
# Figure(1200x500)
# UsageError: Line magic function `%%` not found.
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# Figure(1200x500)
# ...
